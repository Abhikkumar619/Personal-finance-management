# %%
import gdown
import zipfile

# %%
url='https://drive.google.com/file/d/10A5KJ2SyamUocbdQgrezBX1aRHVsB2Xt/view?usp=sharing'
url_code=url.split('/')[-2]
perfix_to_download='https://drive.google.com/uc?/export=download&id='+url_code

# %%
perfix_to_download
# Out:
# 'https://drive.google.com/uc?/export=download&id=10A5KJ2SyamUocbdQgrezBX1aRHVsB2Xt'

# %%
gdown.download(perfix_to_download, "Finance_doc.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=10A5KJ2SyamUocbdQgrezBX1aRHVsB2Xt
# To: /Users/abishekkumaryadav/DataScience/Machine_learning/Personal-finance-management/Finance_doc.zip
# 100%|██████████| 3.09M/3.09M [00:00<00:00, 6.71MB/s]
# 'Finance_doc.zip'

# %%
with zipfile.ZipFile('Finance_doc.zip', 'r') as zip:
    zip.extractall('finance_doc')
